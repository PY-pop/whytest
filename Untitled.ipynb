# %%
import graphviz

# %%
import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
y=iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data=StringIO()
export_graphviz(dtree,out_file=dot_data,filled=True,rounded=True,special_characters=True)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
import numpy as np
A=np.array([1,2,3])
B=np.array([4,3,0])
print('A+B=',np.add(A,B))
print('A-B=',np.subtract(A,B))
# Out:
# A+B= [5 5 3]
# A-B= [-3 -1  3]

# %%
C=np.array([[1,2,3],
            [1,1,1]])
D=np.array([[4,3,9,9],
           [1,1,2,2],
           [4,2,1,1]])
print('np.dot(C,D))=',np.dot(C,D))
print('np.matmul(C,D)=',np.matmul(C,D))
print('         C@D  = ',np.matmul(C,D))

print('np.multiply(D,D)=',np.multiply(D,D))
print('          D*D   =',D*D)
# Out:
# np.dot(C,D))= [[18 11 16 16]
#  [ 9  6 12 12]]
# np.matmul(C,D)= [[18 11 16 16]
#  [ 9  6 12 12]]
#          C@D  =  [[18 11 16 16]
#  [ 9  6 12 12]]
# np.multiply(D,D)= [[16  9 81 81]
#  [ 1  1  4  4]
#  [16  4  1  1]]
#           D*D   = [[16  9 81 81]
#  [ 1  1  4  4]
#  [16  4  1  1]]

# %%
import tensorflow as tf

# %% [markdown]
# Latex

# %% [markdown]
# 插入数学符号
#
# $e^{i\pi}+1=0$
#
# $ \sum_{\forall i}{x_i^{2}} $
#
# 更多小抄：http://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html
#
#           https://reu.dimacs.rutgers.edu/Symbols.pdf

# %% [markdown]
# ![美女图片](http://images01.mopimg.cn/imgs/20180212/20180212_0eaf6eaf2adadd218c8bca84f9a0f3b3.JPEG)

# %% [markdown]
# <img src='./1.jpg',width=200>

# %%
from IPython.display import Image

# %%
Image(filename='./1.jpg',width=200)

# %% [markdown]
# * 插入表格
#
# |一 | 二 | 三 |
# |--:| --:| --:|
# |hel| lo |world|
